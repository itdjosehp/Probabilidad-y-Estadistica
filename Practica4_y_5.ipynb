# %% [markdown]
# <a href="https://colab.research.google.com/github/itdjosehp/Probabilidad-y-Estadistica/blob/main/Practica4_y_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
#
# probabilidad y estadistica
# :Unidad 1
#  practica 4. Tabla de frecuencias y regla de Sturge
#
# Angel Josehp Hernandez Tinoco
#
#  José Gabriel Rodríguez Rivas

# %%
import random
edades=[]
for i in range(100):
  numero_aleatorio=random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [25, 31, 65, 68, 34, 41, 35, 24, 43, 20, 32, 66, 45, 44, 63, 62, 34, 47, 31, 44, 33, 28, 67, 41, 31, 38, 19, 30, 40, 22, 58, 39, 39, 34, 35, 22, 44, 45, 27, 54, 19, 35, 57, 66, 26, 41, 54, 18, 32, 22, 61, 60, 43, 41, 45, 58, 34, 68, 48, 61, 41, 65, 57, 22, 18, 19, 38, 27, 39, 18, 29, 29, 48, 18, 49, 43, 49, 67, 65, 26, 61, 55, 58, 54, 57, 24, 63, 20, 51, 23, 37, 54, 33, 68, 44, 56, 66, 22, 37, 36]

# %%
import pandas as pd

# %%
df=pd.DataFrame(edades,columns=['Edades'])
df.head()
# Out:
#    Edades
# 0      25
# 1      31
# 2      65
# 3      68
# 4      34

# %%
tabla_frecuencias=df['Edades'].value_counts().reset_index()
tabla_frecuencias.columns=['Edades','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edades')
tabla_frecuencias
# Out:
#     Edades  Frecuencia
# 4       18           4
# 17      19           3
# 28      20           2
# 0       22           5
# 33      23           1
# 29      24           2
# 35      25           1
# 19      26           2
# 20      27           2
# 39      28           1
# 24      29           2
# 38      30           1
# 9       31           3
# 27      32           2
# 21      33           2
# 5       34           4
# 6       35           3
# 42      36           1
# 25      37           2
# 22      38           2
# 15      39           3
# 37      40           1
# 1       41           5
# 7       43           3
# 3       44           4
# 11      45           3
# 40      47           1
# 30      48           2
# 18      49           2
# 31      51           1
# 2       54           4
# 32      55           1
# 34      56           1
# 13      57           3
# 16      58           3
# 36      60           1
# 8       61           3
# 41      62           1
# 26      63           2
# 14      65           3
# 10      66           3
# 23      67           2
# 12      68           3

# %%
tabla_frecuencias['Frec Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa
# 4       18           4           0.04
# 17      19           3           0.03
# 28      20           2           0.02
# 0       22           5           0.05
# 33      23           1           0.01
# 29      24           2           0.02
# 35      25           1           0.01
# 19      26           2           0.02
# 20      27           2           0.02
# 39      28           1           0.01
# 24      29           2           0.02
# 38      30           1           0.01
# 9       31           3           0.03
# 27      32           2           0.02
# 21      33           2           0.02
# 5       34           4           0.04
# 6       35           3           0.03
# 42      36           1           0.01
# 25      37           2           0.02
# 22      38           2           0.02
# 15      39           3           0.03
# 37      40           1           0.01
# 1       41           5           0.05
# 7       43           3           0.03
# 3       44           4           0.04
# 11      45           3           0.03
# 40      47           1           0.01
# 30      48           2           0.02
# 18      49           2           0.02
# 31      51           1           0.01
# 2       54           4           0.04
# 32      55           1           0.01
# 34      56           1           0.01
# 13      57           3           0.03
# 16      58           3           0.03
# 36      60           1           0.01
# 8       61           3           0.03
# 41      62           1           0.01
# 26      63           2           0.02
# 14      65           3           0.03
# 10      66           3           0.03
# 23      67           2           0.02
# 12      68           3           0.03

# %%
tabla_frecuencias['Frec Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa  Frec Porcentual
# 4       18           4           0.04              4.0
# 17      19           3           0.03              3.0
# 28      20           2           0.02              2.0
# 0       22           5           0.05              5.0
# 33      23           1           0.01              1.0
# 29      24           2           0.02              2.0
# 35      25           1           0.01              1.0
# 19      26           2           0.02              2.0
# 20      27           2           0.02              2.0
# 39      28           1           0.01              1.0
# 24      29           2           0.02              2.0
# 38      30           1           0.01              1.0
# 9       31           3           0.03              3.0
# 27      32           2           0.02              2.0
# 21      33           2           0.02              2.0
# 5       34           4           0.04              4.0
# 6       35           3           0.03              3.0
# 42      36           1           0.01              1.0
# 25      37           2           0.02              2.0
# 22      38           2           0.02              2.0
# 15      39           3           0.03              3.0
# 37      40           1           0.01              1.0
# 1       41           5           0.05              5.0
# 7       43           3           0.03              3.0
# 3       44           4           0.04              4.0
# 11      45           3           0.03              3.0
# 40      47           1           0.01              1.0
# 30      48           2           0.02              2.0
# 18      49           2           0.02              2.0
# 31      51           1           0.01              1.0
# 2       54           4           0.04              4.0
# 32      55           1           0.01              1.0
# 34      56           1           0.01              1.0
# 13      57           3           0.03              3.0
# 16      58           3           0.03              3.0
# 36      60           1           0.01              1.0
# 8       61           3           0.03              3.0
# 41      62           1           0.01              1.0
# 26      63           2           0.02              2.0
# 14      65           3           0.03              3.0
# 10      66           3           0.03              3.0
# 23      67           2           0.02              2.0
# 12      68           3           0.03              3.0

# %%
tabla_frecuencias['Frec Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 4       18           4           0.04              4.0               4
# 17      19           3           0.03              3.0               7
# 28      20           2           0.02              2.0               9
# 0       22           5           0.05              5.0              14
# 33      23           1           0.01              1.0              15
# 29      24           2           0.02              2.0              17
# 35      25           1           0.01              1.0              18
# 19      26           2           0.02              2.0              20
# 20      27           2           0.02              2.0              22
# 39      28           1           0.01              1.0              23
# 24      29           2           0.02              2.0              25
# 38      30           1           0.01              1.0              26
# 9       31           3           0.03              3.0              29
# 27      32           2           0.02              2.0              31
# 21      33           2           0.02              2.0              33
# 5       34           4           0.04              4.0              37
# 6       35           3           0.03              3.0              40
# 42      36           1           0.01              1.0              41
# 25      37           2           0.02              2.0              43
# 22      38           2           0.02              2.0              45
# 15      39           3           0.03              3.0              48
# 37      40           1           0.01              1.0              49
# 1       41           5           0.05              5.0              54
# 7       43           3           0.03              3.0              57
# 3       44           4           0.04              4.0              61
# 11      45           3           0.03              3.0              64
# 40      47           1           0.01              1.0              65
# 30      48           2           0.02              2.0              67
# 18      49           2           0.02              2.0              69
# 31      51           1           0.01              1.0              70
# 2       54           4           0.04              4.0              74
# 32      55           1           0.01              1.0              75
# 34      56           1           0.01              1.0              76
# 13      57           3           0.03              3.0              79
# 16      58           3           0.03              3.0              82
# 36      60           1           0.01              1.0              83
# 8       61           3           0.03              3.0              86
# 41      62           1           0.01              1.0              87
# 26      63           2           0.02              2.0              89
# 14      65           3           0.03              3.0              92
# 10      66           3           0.03              3.0              95
# 23      67           2           0.02              2.0              97
# 12      68           3           0.03              3.0             100

# %% [markdown]
# Regla de sturge

# %%
import math

# %%
print(edades)
# Out:
# [25, 31, 65, 68, 34, 41, 35, 24, 43, 20, 32, 66, 45, 44, 63, 62, 34, 47, 31, 44, 33, 28, 67, 41, 31, 38, 19, 30, 40, 22, 58, 39, 39, 34, 35, 22, 44, 45, 27, 54, 19, 35, 57, 66, 26, 41, 54, 18, 32, 22, 61, 60, 43, 41, 45, 58, 34, 68, 48, 61, 41, 65, 57, 22, 18, 19, 38, 27, 39, 18, 29, 29, 48, 18, 49, 43, 49, 67, 65, 26, 61, 55, 58, 54, 57, 24, 63, 20, 51, 23, 37, 54, 33, 68, 44, 56, 66, 22, 37, 36]

# %%
df=pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     25
# 1     31
# 2     65
# 3     68
# 4     34
# ..   ...
# 95    56
# 96    66
# 97    22
# 98    37
# 99    36
#
# [100 rows x 1 columns]

# %%
n=len(edades)
k=int(1+math.log2(100))
print("valor de n:",n,"\nNumero de intervalos:",k )
# Out:
# valor de n: 100
# Numero de intervalos: 7

# %%
tabla_frecuencias=pd.cut(df['Edad'],bins=k,include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns=['Clase','Frec']
tabla_frecuencias
# Out:
#                           Clase  Frec
# 0  (17.948999999999998, 25.143]    18
# 1              (32.286, 39.429]    17
# 2                (60.857, 68.0]    17
# 3              (39.429, 46.571]    16
# 4              (25.143, 32.286]    13
# 5              (53.714, 60.857]    13
# 6              (46.571, 53.714]     6

# %%
tabla_frecuencias=tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias
# Out:
#                           Clase  Frec
# 0  (17.948999999999998, 25.143]    18
# 4              (25.143, 32.286]    13
# 1              (32.286, 39.429]    17
# 3              (39.429, 46.571]    16
# 6              (46.571, 53.714]     6
# 5              (53.714, 60.857]    13
# 2                (60.857, 68.0]    17

# %%
tabla_frecuencias['Frec Rel']=tabla_frecuencias['Frec']/n
tabla_frecuencias['Frec Por']=tabla_frecuencias['Frec']/n*100
tabla_frecuencias['Frec Ac']=tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac']=tabla_frecuencias['Frec Rel'].cumsum()
tabla_frecuencias['frec por Ac']=tabla_frecuencias['Frec Por'].cumsum()
print(tabla_frecuencias)
# Out:
#                           Clase  Frec  Frec Rel  Frec Por  Frec Ac  \
# 0  (17.948999999999998, 25.143]    18      0.18      18.0       18
# 4              (25.143, 32.286]    13      0.13      13.0       31
# 1              (32.286, 39.429]    17      0.17      17.0       48
# 3              (39.429, 46.571]    16      0.16      16.0       64
# 6              (46.571, 53.714]     6      0.06       6.0       70
# 5              (53.714, 60.857]    13      0.13      13.0       83
# 2                (60.857, 68.0]    17      0.17      17.0      100
#
#    Frec Rel Ac  frec por Ac
# 0         0.18         18.0
# 4         0.31         31.0
# 1         0.48         48.0
# 3         0.64         64.0
# 6         0.70         70.0
# 5         0.83         83.0
# 2         1.00        100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades,alpha=0.5)
plt.title('Histograma de edades')
# Out:
# Text(0.5, 1.0, 'Histograma de edades')

# %%
plt.hist(df['Edad'],bins=k,alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
#
# probabilidad y estadistica
# :Unidad 1
#  practica 5. Diagramas de Cajas y bigotes.
#
# Angel Josehp Hernandez Tinoco
#
#  José Gabriel Rodríguez Rivas

# %%
import random
edades2=[]
for i in range(100):
  numero_aleatorio2=random.randint(20, 87)
  edades2.append(numero_aleatorio2)
print(edades2)
# Out:
# [56, 77, 32, 29, 40, 34, 47, 52, 65, 34, 61, 50, 84, 33, 31, 76, 73, 73, 44, 32, 67, 28, 39, 20, 44, 44, 46, 78, 74, 36, 64, 71, 30, 73, 59, 51, 41, 66, 24, 47, 58, 63, 31, 64, 82, 65, 20, 65, 23, 86, 65, 22, 69, 59, 67, 79, 38, 60, 27, 44, 61, 22, 56, 57, 55, 74, 39, 22, 48, 67, 85, 21, 81, 34, 24, 40, 69, 21, 42, 63, 54, 57, 24, 68, 80, 78, 28, 62, 83, 50, 52, 38, 69, 54, 48, 52, 47, 42, 78, 33]

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(edades,
                   vert=True,
                   patch_artist=True)
ax1.set_title('Edades encuesta 1')
bplot2=ax2.boxplot(edades2,
                   vert=True,
                   patch_artist=True)
ax2.set_title('Edades encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig,(ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1=ax1.boxplot(edades,
                   vert=True,
                   patch_artist=True)
ax1.set_title('Edades encuesta 1')
bplot2=ax2.boxplot(edades2,
                   vert=True,
                   patch_artist=True)
ax2.set_title('Edades encuesta 2')
plt.show()
