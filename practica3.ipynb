# %% [markdown]
# <a href="https://colab.research.google.com/github/itdjosehp/Probabilidad-y-Estadistica/blob/main/practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
#
# probabilidad y estadistica
# facilitador:Unidad 1
#  practica 3. Maximo,minimo,rango y dispersión de datos
#
# Angel Josehp Hernandez Tinoco
#
#  José Gabriel Rodríguez Rivas

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1=[]
for i in range(100):
    numero_aleatorio=round(random.uniform(50,100),2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [77.29, 70.42, 93.69, 83.83, 94.12, 51.57, 83.36, 88.32, 53.16, 91.57, 82.75, 91.89, 52.08, 50.5, 63.35, 71.92, 96.38, 63.71, 89.29, 83.35, 67.68, 68.92, 76.14, 90.73, 87.52, 71.43, 71.89, 52.37, 62.41, 94.34, 83.63, 66.23, 56.63, 63.97, 96.91, 56.97, 66.01, 85.77, 58.17, 89.03, 89.68, 51.27, 93.25, 59.54, 63.02, 57.01, 87.95, 85.65, 51.58, 89.73, 61.67, 90.53, 59.21, 93.17, 58.49, 99.96, 64.86, 81.04, 55.87, 61.02, 75.78, 55.21, 54.09, 59.01, 70.43, 89.1, 99.48, 79.98, 83.59, 79.53, 85.82, 94.09, 88.47, 95.67, 62.12, 52.53, 90.02, 85.51, 99.5, 71.64, 77.67, 58.49, 87.43, 74.86, 93.92, 53.33, 99.18, 53.19, 86.46, 52.65, 56.54, 57.14, 67.95, 81.43, 71.08, 80.56, 62.5, 65.67, 79.06, 84.79]

# %%
fabrica2=[]
for i in range(100):
    numero_aleatorio2=round(random.uniform(50,100),2)
    fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [55.52, 68.44, 59.13, 67.29, 54.44, 87.87, 76.55, 54.31, 74.26, 57.08, 75.57, 85.18, 59.39, 61.97, 51.6, 98.8, 97.36, 82.01, 56.56, 92.25, 95.97, 56.46, 64.3, 68.91, 66.88, 51.97, 68.29, 53.47, 67.57, 82.67, 64.71, 95.39, 68.85, 54.27, 67.83, 87.87, 76.84, 54.78, 93.81, 67.57, 60.04, 60.77, 99.54, 71.45, 63.22, 66.84, 72.81, 94.29, 89.73, 96.98, 96.98, 98.04, 74.11, 67.24, 82.43, 81.53, 59.96, 54.29, 59.86, 70.33, 50.3, 67.17, 86.57, 98.87, 78.51, 97.54, 54.59, 63.31, 67.7, 77.15, 68.81, 59.03, 71.91, 53.33, 55.07, 90.05, 57.07, 82.4, 62.93, 51.88, 61.71, 66.85, 55.51, 62.43, 57.63, 74.62, 55.6, 52.88, 93.11, 59.45, 89.68, 68.58, 97.87, 97.7, 72.53, 73.98, 66.0, 63.57, 72.52, 88.09]

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("estadistica descriptiva de la fabrica 1\n", "media =", mediana1,
    "\n mediana= ", mediana1, "\n moda = ", moda1, "\n moda = ", moda1, "\n maximo = ", maximo1,
      "\n minimo = ", minimo1, "\n rango = ",rango1)
# Out:
# estadistica descriptiva de la fabrica 1
#  media = 75.96000000000001
#  mediana=  75.96000000000001
#  moda =  58.49
#  moda =  58.49
#  maximo =  99.96
#  minimo =  50.5
#  rango =  49.459999999999994

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("estadistica descriptiva de la fabrica 2\n", "media =", mediana2,
    "\n mediana= ", mediana2, "\n moda = ", moda2, "\n moda = ", moda2, "\n maximo = ", maximo2,
      "\n minimo = ", minimo2, "\n rango = ",rango2)
# Out:
# estadistica descriptiva de la fabrica 2
#  media = 68.06
#  mediana=  68.06
#  moda =  87.87
#  moda =  87.87
#  maximo =  99.54
#  minimo =  50.3
#  rango =  49.24000000000001

# %%
desviacion_estandar_fabrica1=stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 15.170516518043888

# %%
desviacion_estandar_fabrica2=stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 14.753517865378427

# %%
plt. figure(figsize = (8,6) )
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed',
linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt. figure(figsize = (8,6) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed',
linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
