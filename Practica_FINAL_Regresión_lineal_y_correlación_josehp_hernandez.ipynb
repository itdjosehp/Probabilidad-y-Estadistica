# %% [markdown]
# <a href="https://colab.research.google.com/github/itdjosehp/Probabilidad-y-Estadistica/blob/main/Practica_FINAL_Regresi%C3%B3n_lineal_y_correlaci%C3%B3n_josehp_hernandez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![image.png](data:image/png;base64,...)
#
# probabilidad y estadistica:
# Unidad 5
#
# Angel Josehp Hernandez Tinoco
#
#  José Gabriel Rodríguez Rivas

# %%
import pandas as pd
df1 = pd.read_csv("grupo1.csv")
display(df1.head())
df2 = pd.read_csv("grupo2.csv")
display(df2.head())
df3 = pd.read_csv("grupo3.csv")
display(df3.head())
# Out:
#    HorasEstudio  Calificacion
# 0         20.00         75.94
# 1         15.60         87.48
# 2         17.91         79.40
# 3         20.00         73.37
# 4         20.00         83.75
#    HorasEstudio  Calificacion
# 0          3.79          40.0
# 1          6.08          26.1
# 2          7.17          29.0
# 3          7.54          31.9
# 4          8.18          34.8
#    HorasEstudio  Calificacion
# 0          3.79          15.0
# 1          6.08          26.1
# 2          7.17          29.0
# 3          7.54          31.9
# 4          8.18          34.8

# %%
import matplotlib.pyplot as plt

print("Estadísticas Descriptivas para Grupo 1:")
print(df1[["HorasEstudio", "Calificacion"]].describe())
print("\n")

plt.figure(figsize=(10, 5))
plt.hist(df1["Calificacion"], bins=10, edgecolor="black")
plt.title("Histograma de Calificaciones para Grupo 1")
plt.xlabel("Calificación Final")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# Estadísticas Descriptivas para Grupo 1:
#        HorasEstudio  Calificacion
# count     50.000000      50.00000
# mean      14.352000      83.78820
# std        4.219174       7.83389
# min        3.790000      68.46000
# 25%       12.032500      78.03500
# 50%       14.600000      84.49000
# 75%       17.715000      88.09000
# max       20.000000     100.00000

# %%
print("Estadísticas Descriptivas para Grupo 2:\n")
print(df2[["HorasEstudio", "Calificacion"]].describe())
print("\n")

plt.figure(figsize=(10, 5))
plt.hist(df2["Calificacion"], bins=10, edgecolor="black")
plt.title("Histograma de calificaciones para Grupo 2")
plt.xlabel("Calificación Final")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# Estadísticas Descriptivas para Grupo 2:
#
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.912000
# std        4.219174     20.668922
# min        3.790000     26.100000
# 25%       12.032500     63.500000
# 50%       14.600000     78.550000
# 75%       17.715000     93.300000
# max       20.000000     99.000000

# %%
print("Estadísticas Descriptivas para Grupo 3:\n")
print(df3[["HorasEstudio", "Calificacion"]].describe())
print("\n")

plt.figure(figsize=(10, 5))
plt.hist(df3["Calificacion"], bins=10, edgecolor="black")
plt.title("Histograma de calificaciones para Grupo 3")
plt.xlabel("Calificación Final")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# Estadísticas Descriptivas para Grupo 3:
#
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.968000
# std        4.219174     23.668867
# min        3.790000     15.000000
# 25%       12.032500     61.000000
# 50%       14.600000     84.950000
# 75%       17.715000     94.375000
# max       20.000000     99.000000

# %%
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
#Grupo 1
X_g1 = df1[['HorasEstudio']]
y_g1 = df1['Calificacion']

# Entrenar el modelo de regresión lineal
modelo_rl_g1 = LinearRegression()
modelo_rl_g1.fit(X_g1, y_g1)

# Obtener la pendiente e intercepto
pendiente_g1 = modelo_rl_g1.coef_[0]
intercepto_g1 = modelo_rl_g1.intercept_

print("\nModelo de Regresión Lineal Grupo 1")
print(f"Ecuación de la línea de regresión: Calificacion = {pendiente_g1:.2f} * HorasEstudio + {intercepto_g1:.2f}")

# Calcular el coeficiente de correlación de Pearson
correlacion_g1, _ = pearsonr(df1['HorasEstudio'], df1['Calificacion'])
print(f"Coeficiente de correlación de Pearson (r): {correlacion_g1:.2f}")
# Out:
# Modelo de Regresión Lineal Grupo 1
# Ecuación de la línea de regresión: Calificacion = -0.11 * HorasEstudio + 85.31
# Coeficiente de correlación de Pearson (r): -0.06

# %%
#Grupo 2
X_g2 = df2[['HorasEstudio']]
y_g2 = df2['Calificacion']

# Entrenar el modelo de regresión lineal
modelo_rl_g2 = LinearRegression()
modelo_rl_g2.fit(X_g2, y_g2)

# Obtener la pendiente e intercepto
pendiente_g2 = modelo_rl_g2.coef_[0]
intercepto_g2 = modelo_rl_g2.intercept_

print("\nModelo de Regresión Lineal Grupo 2")
print(f"Ecuación de la línea de regresión: Calificacion = {pendiente_g2:.2f} * HorasEstudio + {intercepto_g2:.2f}")

# Calcular el coeficiente de correlación de Pearson
correlacion_g2, _ = pearsonr(df2['HorasEstudio'], df2['Calificacion'])
print(f"Coeficiente de correlación de Pearson (r): {correlacion_g2:.2f}")
# Out:
# Modelo de Regresión Lineal Grupo 2
# Ecuación de la línea de regresión: Calificacion = 4.22 * HorasEstudio + 15.31
# Coeficiente de correlación de Pearson (r): 0.86

# %%
#Grupo 3
X_g3 = df3[['HorasEstudio']]
y_g3 = df3['Calificacion']

# Entrenar el modelo de regresión lineal
modelo_rl_g3 = LinearRegression()
modelo_rl_g3.fit(X_g3, y_g3)

# Obtener la pendiente e intercepto
pendiente_g3 = modelo_rl_g3.coef_[0]
intercepto_g3 = modelo_rl_g3.intercept_

print("\nModelo de Regresión Lineal Grupo 3")
print(f"Ecuación de la línea de regresión: Calificacion = {pendiente_g3:.2f} * HorasEstudio + {intercepto_g3:.2f}")

# Calcular el coeficiente de correlación de Pearson
correlacion_g3, _ = pearsonr(df3['HorasEstudio'], df3['Calificacion'])
print(f"Coeficiente de correlación de Pearson (r): {correlacion_g3:.2f}")
# Out:
# Modelo de Regresión Lineal Grupo 3
# Ecuación de la línea de regresión: Calificacion = 5.29 * HorasEstudio + 0.11
# Coeficiente de correlación de Pearson (r): 0.94

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.scatterplot(x='HorasEstudio', y='Calificacion', data=df1, label='Datos del Grupo 1')
plt.plot(df1['HorasEstudio'], modelo_rl_g1.predict(df1[['HorasEstudio']]), color='red', label=f'Regresión Lineal (y={pendiente_g1:.2f}x + {intercepto_g1:.2f})')
plt.title('Relación entre Horas de Estudio y Calificación - Grupo 1')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificación Final')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='HorasEstudio', y='Calificacion', data=df2, label='Datos del Grupo 2')
plt.plot(df2['HorasEstudio'], modelo_rl_g2.predict(df2[['HorasEstudio']]), color='red', label=f'Regresión Lineal (y={pendiente_g2:.2f}x + {intercepto_g2:.2f})')
plt.title('Relación entre Horas de Estudio y Calificación - Grupo 2')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificación Final')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='HorasEstudio', y='Calificacion', data=df3, label='Datos del Grupo 3')
plt.plot(df3['HorasEstudio'], modelo_rl_g3.predict(df3[['HorasEstudio']]), color='red', label=f'Regresión Lineal (y={pendiente_g3:.2f}x + {intercepto_g3:.2f})')
plt.title('Relación entre Horas de Estudio y Calificación - Grupo 3')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificación Final')
plt.legend()
plt.grid(True)
plt.show()

# %%
from scipy.stats import pearsonr
correlacion_g1, _ = pearsonr(df1['HorasEstudio'], df1['Calificacion'])
print("Coeficiente de Correlación de Pearson Grupo 1")
print(f"Coeficiente de correlación (r): {correlacion_g1:.2f}")
# Out:
# Coeficiente de Correlación de Pearson Grupo 1
# Coeficiente de correlación (r): -0.06

# %%
correlacion_g2, _ = pearsonr(df2['HorasEstudio'], df2['Calificacion'])
print("Coeficiente de Correlación de Pearson Grupo 2")
print(f"Coeficiente de correlación (r): {correlacion_g2:.2f}")
# Out:
# Coeficiente de Correlación de Pearson Grupo 2
# Coeficiente de correlación (r): 0.86

# %%
correlacion_g3, _ = pearsonr(df3['HorasEstudio'], df3['Calificacion'])
print("Coeficiente de Correlación de Pearson Grupo 3")
print(f"Coeficiente de correlación (r): {correlacion_g3:.2f}")
# Out:
# Coeficiente de Correlación de Pearson Grupo 3
# Coeficiente de correlación (r): 0.94

# %% [markdown]
# ### Grupo 1:
#
# Diagrama de dispersión:Los datos representados en el gráfico sugieren una relación directa entre las horas dedicadas al estudio y la calificación obtenida. A medida que las horas de estudio aumentan, las calificaciones tienden a ser más altas.
#
# Línea de regresión (visual):
# Si dibujáramos una línea que mejor se ajustara a estos puntos, esta línea mostraría una inclinación hacia arriba, lo que confirma la tendencia positiva observada.
#
# Coeficiente de correlación (estimado):
# Basándonos en la dispersión de los puntos, se estima que existe una correlación positiva de intensidad moderada a fuerte entre las variables.
#
# Coeficiente de regresión:
# Se anticipa que por cada hora adicional de estudio, la calificación final experimentará un incremento. El valor preciso de este aumento se determinará mediante cálculos específicos.
#
# Coeficiente de correlación:
# Se observa una vinculación positiva entre la cantidad de horas de estudio invertidas y la calificación final alcanzada. La solidez de esta conexión se sitúa entre moderada y fuerte.
#
# Significado del modelo:
# Para poder afirmar si el modelo predictivo es estadísticamente relevante, se requiere conocer el valor p asociado. Sin esta información, no podemos establecer la significancia estadística del modelo.
#
# Confiabilidad del modelo:
# La fiabilidad del modelo estará determinada por la proximidad de los puntos individuales a la línea de regresión. A simple vista, la dispersión de los puntos sugiere una confiabilidad razonable.

# %% [markdown]
# ## Grupo 2:
#
# Diagrama de dispersión:
# En este caso, los puntos en el gráfico muestran una mayor dispersión, aunque se insinúa una ligera tendencia hacia arriba.
#
# Línea de regresión (visual):
# Si se dibujara una línea de mejor ajuste, probablemente tendría una inclinación positiva, pero esta sería menos pronunciada que la observada en el Grupo 1.
#
# Coeficiente de correlación (estimado):
# Se estima que la correlación entre las variables es positiva, pero de una intensidad que oscila entre débil y moderada.
#
# Coeficiente de regresión:
# Se prevé que por cada hora adicional dedicada al estudio, la calificación final experimentará un incremento modesto.
#
# Coeficiente de correlación:
# Se identifica una relación positiva entre las horas de estudio y la calificación final, aunque esta conexión no parece ser particularmente fuerte.
#
# Significado del modelo:
# La ausencia del valor p impide determinar con certeza si el modelo predictivo tiene significancia estadística.
#
# Confiabilidad del modelo:
# Considerando la dispersión de los datos, es posible que el modelo no sea altamente confiable para realizar predicciones precisas.

# %% [markdown]
# ## Grupo 3:
#
# Diagrama de dispersión:
# Al igual que en el Grupo 2, los puntos en el gráfico se encuentran bastante dispersos, sugiriendo una posible, aunque tenue, tendencia ascendente.
#
# Línea de regresión (visual):
# La línea de mejor ajuste que se podría trazar probablemente tendría una pendiente positiva, pero esta sería de magnitud pequeña.
#
# Coeficiente de correlación (estimado):
# Se estima que la correlación entre las variables es positiva, pero de carácter débil.
#
# Coeficiente de regresión:
# Se esperaría que por cada hora adicional de estudio, la calificación final experimentara un incremento ligero.
#
# Coeficiente de correlación:
# La conexión entre la cantidad de horas dedicadas al estudio y la calificación final obtenida es positiva, aunque su fuerza es limitada.
#
# Significado del modelo:
# La falta del valor p impide asegurar si el modelo predictivo es estadísticamente significativo.
#
# Confiabilidad del modelo:
# Considerando la dispersión de los datos, es probable que el modelo no sea muy fiable para realizar predicciones con exactitud.
